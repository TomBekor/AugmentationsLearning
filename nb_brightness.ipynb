# %%
import os
import glob

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.parameter import Parameter

import torchvision
from torchvision import transforms

import kornia as K

import matplotlib.pyplot as plt
from PIL import Image

from AugmentationsDataset import *

from utils import plot_tensor, show_sample, learning_grid, create_loss_map

# %%
### --- Config --- ###
augmentation = 'brightness'
# dataset
target_param_val = .5

init_param_val = 0.
# training
batch_size = 64
epochs = 1
lr=0.01
momentum=0.9
scheduler_iters = 10
use_scheduler=False

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# paths:
run_name = f'{augmentation}-init-{init_param_val}_target-{target_param_val}'

figures_dir = f'figures'
run_figures_dir = f'{figures_dir}/{run_name}'

gifs_dir = f'gifs'
run_gif_name = f'{gifs_dir}/{run_name}.gif'

os.makedirs(run_figures_dir, exist_ok=True)
os.makedirs(gifs_dir, exist_ok=True)

# %%
source_transform = transforms.Compose([
    transforms.ToTensor()
])

target_augmentations = transforms.Compose([
    K.augmentation.container.ImageSequential(
        K.enhance.AdjustBrightness(brightness_factor=target_param_val)
        # K.augmentation.ColorJiggle(brightness=target_param_val)
    )
])
target_transform = transforms.Compose([
    transforms.ToTensor(),
    target_augmentations
])

# %%
glob_path = '../data/tiny-imagenet-200/train/*/images/*'
dataset = AugmentationsDataset(glob_path,
                               source_transform, target_transform,)

# %%
show_sample(dataset[0])

# %%
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                         shuffle=True)

# %%
class AugmentationNetwork(nn.Module):
    def __init__(self, init_param_val):
        super().__init__()
        self.trans_param = Parameter(torch.Tensor([init_param_val]))

    def forward(self, x):
        clamped_param = torch.clamp(self.trans_param, min=0.0, max=1.0)
        # clamped_param = torch.nn.Sigmoid()(self.trans_param)
        # clamped_param = torch.clamp(self.trans_param, min=-360.0, max=360.0)
        # clamped_param = torch.remainder(self.trans_param, 360.0)
        augmenter = K.augmentation.container.ImageSequential(
            K.enhance.AdjustBrightness(brightness_factor=clamped_param)
            # K.augmentation.ColorJiggle(brightness=target_param_val)
        )
        out = augmenter(x)
        return out

# %%
model = AugmentationNetwork(init_param_val=init_param_val)
model.to(device)
# Out:
# AugmentationNetwork()

# %%
for name, param in model.named_parameters():
    if param.requires_grad:
        print(name, param.data)
# Out:
# trans_param tensor([0.], device='cuda:0')

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
# optimizer = optim.Adam(model.parameters(), lr=lr)
# scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.93, last_epoch=-1, verbose=False)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0.1, verbose=True)
# Out:
# Adjusting learning rate of group 0 to 1.0000e-02.

# %%
losses = []
lrs = []
p_progress = []
for epoch in range(epochs):

    running_loss = 0.0
    for i, data in enumerate(dataloader):
        source_images, target_images = data
        source_images, target_images = source_images.to(device), target_images.to(device)
        
        optimizer.zero_grad()

        output_images = model(source_images)
        loss = criterion(output_images, target_images)
        loss.backward()
        optimizer.step()

        losses.append(loss.item())
        running_loss += loss.item()
        print_every = 10
        if i % print_every == print_every - 1:
            print(f'[Epoch: {epoch+1} | Batch: {i+1} | MSE Loss: {running_loss/print_every:.3f} | {model.trans_param.item()}]')
            running_loss = 0.0

            with torch.no_grad():
                img_dict = {
                    "source": dataset[0][0],
                    "model's output": model(dataset[0][0]).squeeze(),
                    "target": dataset[0][1]
                }
                learning_grid(img_dict, save=f'{run_figures_dir}/epoch-{epoch+1:02}_batch-{i+1:05}.png')
        
        lrs.append(scheduler.get_last_lr())
        p_progress.append(model.trans_param.item())
        if use_scheduler:
            if i % scheduler_iters == scheduler_iters - 1 and i > 100:
                scheduler.step()


        if i == 1000:
            break

print('Finished Training.')
# Out:
# [Epoch: 1 | Batch: 10 | MSE Loss: 0.121 | 0.28370609879493713]
# [Epoch: 1 | Batch: 20 | MSE Loss: 0.008 | 0.5656846165657043]
# [Epoch: 1 | Batch: 30 | MSE Loss: 0.006 | 0.6285629272460938]
# [Epoch: 1 | Batch: 40 | MSE Loss: 0.006 | 0.5806275606155396]
# [Epoch: 1 | Batch: 50 | MSE Loss: 0.002 | 0.5160871148109436]
# [Epoch: 1 | Batch: 60 | MSE Loss: 0.000 | 0.48316556215286255]
# [Epoch: 1 | Batch: 70 | MSE Loss: 0.000 | 0.4835323393344879]
# [Epoch: 1 | Batch: 80 | MSE Loss: 0.000 | 0.49522864818573]
# [Epoch: 1 | Batch: 90 | MSE Loss: 0.000 | 0.5026558637619019]
# [Epoch: 1 | Batch: 100 | MSE Loss: 0.000 | 0.5034236311912537]
# [Epoch: 1 | Batch: 110 | MSE Loss: 0.000 | 0.5013620853424072]
# [Epoch: 1 | Batch: 120 | MSE Loss: 0.000 | 0.49970340728759766]
# [Epoch: 1 | Batch: 130 | MSE Loss: 0.000 | 0.4993242025375366]
# [Epoch: 1 | Batch: 140 | MSE Loss: 0.000 | 0.4996553361415863]
# [Epoch: 1 | Batch: 150 | MSE Loss: 0.000 | 0.5000080466270447]
# [Epoch: 1 | Batch: 160 | MSE Loss: 0.000 | 0.5001246333122253]
# [Epoch: 1 | Batch: 170 | MSE Loss: 0.000 | 0.5000784993171692]
# [Epoch: 1 | Batch: 180 | MSE Loss: 0.000 | 0.5000081062316895]
# [Epoch: 1 | Batch: 190 | MSE Loss: 0.000 | 0.4999780058860779]
# [Epoch: 1 | Batch: 200 | MSE Loss: 0.000 | 0.4999828338623047]
# [Epoch: 1 | Batch: 210 | MSE Loss: 0.000 | 0.4999963939189911]
# [Epoch: 1 | Batch: 220 | MSE Loss: 0.000 | 0.5000036358833313]
# [Epoch: 1 | Batch: 230 | MSE Loss: 0.000 | 0.5000036358833313]
# [Epoch: 1 | Batch: 240 | MSE Loss: 0.000 | 0.5000012516975403]
# [Epoch: 1 | Batch: 250 | MSE Loss: 0.000 | 0.4999995231628418]
# [Epoch: 1 | Batch: 260 | MSE Loss: 0.000 | 0.4999992549419403]
# [Epoch: 1 | Batch: 270 | MSE Loss: 0.000 | 0.4999997019767761]
# [Epoch: 1 | Batch: 280 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 290 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 300 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 310 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 320 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 330 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 340 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 350 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 360 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 370 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 380 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 390 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 400 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 410 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 420 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 430 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 440 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 450 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 460 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 470 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 480 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 490 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 500 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 510 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 520 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 530 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 540 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 550 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 560 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 570 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 580 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 590 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 600 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 610 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 620 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 630 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 640 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 650 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 660 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 670 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 680 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 690 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 700 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 710 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 720 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 730 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 740 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 750 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 760 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 770 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 780 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 790 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 800 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 810 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 820 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 830 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 840 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 850 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 860 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 870 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 880 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 890 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 900 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 910 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 920 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 930 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 940 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 950 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 960 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 970 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 980 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 990 | MSE Loss: 0.000 | 0.5]
# [Epoch: 1 | Batch: 1000 | MSE Loss: 0.000 | 0.5]
# Finished Training.

# %%
os.makedirs(f'{run_figures_dir}/results', exist_ok=True)

# %%
param_linspace = np.linspace(0.,1.,361)
loss_map = create_loss_map(AugmentationNetwork, param_linspace,
                           dataloader, criterion,
                           save=run_name)
p_progress = [p % 1. for p in p_progress]
p_progress_losses = [loss_map[np.argmin([abs(p-pg) for p in param_linspace])] for pg in p_progress]
final_param = model.trans_param.item() % 1.
final_param = np.argmin([abs(p-final_param) for p in param_linspace])
statring_point = init_param_val
statring_point = np.argmin([abs(p-statring_point) for p in param_linspace])
plt.plot(param_linspace, loss_map, zorder=2)
plt.scatter(param_linspace[statring_point], y=[loss_map[statring_point]], marker='*', c='b', s=80, zorder=4)
plt.scatter(param_linspace[final_param], y=[loss_map[final_param]], marker='*', c='r', s=80, zorder=4)
plt.plot(p_progress, p_progress_losses, c='orange', zorder=3)
plt.title('Loss map')
plt.xlabel('transformation parameter')
plt.ylabel('loss')
plt.savefig(f'{run_figures_dir}/results/loss_map.png')

# %%
len(p_progress)
# Out:
# 1001

# %%
plt.plot(p_progress, zorder=7)
plt.hlines(y=[target_param_val], xmin=[0], xmax=[len(p_progress)], color='r',zorder=5)
plt.xlabel('iteration')
plt.ylabel('parameter')
plt.title('Parameter progress')
plt.savefig(f'{run_figures_dir}/results/parameter_progress.png')

# %%
plt.plot(losses)
plt.title('Training loss')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.savefig(f'{run_figures_dir}/results/training_loss.png')

# %%
plt.plot(lrs)
plt.title('Learning rate')
plt.xlabel('iteration')
plt.ylabel('lr')
plt.savefig(f'{run_figures_dir}/results/learning_rate.png')

# %%
num_frames = 50
# filepaths
fp_in = f"{run_figures_dir}/epoch-*"
fp_out = run_gif_name

imgs = iter([Image.open(f) for f in sorted(glob.glob(fp_in))][:num_frames])
img = next(imgs)  # extract first image from iterator
img.save(fp=fp_out, format='GIF', append_images=imgs,
         save_all=True, duration=75, loop=0)
